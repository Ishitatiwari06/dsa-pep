# %%
queue=[]
queue.append(1)
queue.append(2)
queue.append(3)
queue.pop(0)
print(queue)
# Out:
# [2, 3]

# %%
from collections import deque

q=deque()
q.append(10)
q.append(20)
q.append(30)
q.popleft()
print(q)
# Out:
# deque([20, 30])

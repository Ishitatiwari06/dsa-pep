# %%
# ll implementation
class Node:
  def __init__(self,data):
    self.data=data
    self.next=None

# %%
  # insert/delete at head
class Stack:
  def __init__(self):
    self.top=None
  def push(self,x):
    node=Node(x)
    node.next=self.top
    self.top=node
    return self.top
  def pop(self):
    if self.top is None:
      return "Underflow"
    value=self.top.data
    self.top=self.top.next
    return value
  def peek(self):
    pass
  def isEmpty(self):
    return self.top is None
  def size(self):
    cnt=0
    temp=self.top
    while temp:
      cnt+=1
      temp-temp.next
    return cnt
